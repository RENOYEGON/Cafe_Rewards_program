# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Setting to make numbers easier to read on display
pd.options.display.float_format = '{:20.2f}'.format

# Show all columns on output
pd.set_option('display.max_columns', 999)

# %%
# Load CSVs
offers_original = pd.read_csv(r"C:\Users\USER\Downloads\Maven_Cafe\Data\offers.csv")
customers_original = pd.read_csv(r"C:\Users\USER\Downloads\Maven_Cafe\Data\customers.csv")
events_original = pd.read_csv(r"C:\Users\USER\Downloads\Maven_Cafe\Data\events.csv", low_memory=False)

# %%
# Make copies to work on safely
offers = offers_original.copy()
customers = customers_original.copy()
events = events_original.copy()

# %%
offers.info()
customers.info()
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   offer_id    10 non-null     object
#  1   offer_type  10 non-null     object
#  2   difficulty  10 non-null     int64
#  3   reward      10 non-null     int64
#  4   duration    10 non-null     int64
#  5   channels    10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 612.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       17000 non-null  object
#  1   became_member_on  17000 non-null  int64
#  2   gender            14825 non-null  object
#  3   age               17000 non-null  int64
#  4   income            14825 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# ...

# %%
customers.isnull().sum()
events.isnull().sum()
offers.isnull().sum()
# Out:
# offer_id      0
# offer_type    0
# difficulty    0
# reward        0
# duration      0
# channels      0
# dtype: int64

# %%
customers['gender'].value_counts().plot(kind='bar')
customers['age'].hist()
customers['income'].hist()
# Out:
# <Axes: xlabel='gender'>

# %%
offers['offer_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='offer_type'>

# %%
events['event'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='event'>

# %%
events.groupby('time')['event'].count().plot()
# Out:
# <Axes: xlabel='time'>

# %%
customers[customers["age"] == 118]["customer_id"].nunique()
# Out:
# 2175
